# %% [raw]
# ---
# title: "PIL vs OpenCV"
# date: 2018-09-24
# type: technical_note
# ---

# %% [markdown]
# As I'm standing on the precipice of doing a bunch of image processing/classification, it occurs to me that I don't know a whole lot about the available tools and packages for working with images. The following is a look at the two more-popular libraries.
#
# `PIL` and `cv2` both support general image processing, such as:
#
# - Conversion between image types
# - Image transformation
# - Image filtering

# %% [markdown]
# ## PIL (Pillow)

# %% [markdown]
# The Python Image Library
#
# - Easy to use
# - Lightweight
#
# Use when you want to cut and resize images, or do *simple* manipulation.

# %% [markdown]
# ### Installing

# %% [markdown]
# Although you import the library as `PIL`, you have to install it using
#
# ```
# pip install Pillow
# ```

# %% [markdown]
# ### Use

# %%
from PIL import Image

im = Image.open('images/daisy.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x533 at 0x4FEE6A0>

# %% [markdown]
# ### Documentation

# %% [markdown]
# [Handbook here](https://pillow.readthedocs.io/en/3.0.x/handbook/index.html)

# %% [markdown]
# ## cv2 (Open CV)

# %% [markdown]
# Used for **C**omputer **V**ision, hence is a much more robust package.
#
# - *Loaded* with algorithms well-suited for data science and vision-based robotics.
#
# **Although, it bears a warning** that the library, annoyingly, defaults to reading/writing everything as BGR, instead of the intuitive RGB, because "reasons." [Here's an excellent post](https://www.learnopencv.com/why-does-opencv-use-bgr-color-format/) trying to explain why.

# %% [markdown]
# ### Installing

# %% [markdown]
# Not to be outdone, getting ahold of `cv2` is even more cryptic than `PIL`.
#
# ```
# pip install opencv-python
# ```

# %% [markdown]
# ### Use

# %% [markdown]
# Whereas `PIL` reads an image to an Image, `cv2` cuts right to the chase and stores it as a `np.array`

# %%
import cv2

im = cv2.imread('images/daisy.jpg')
im.shape
# Out:
# (533, 400, 3)

# %% [markdown]
# Requiring us to lean on `matplotlib` to inspect the image

# %%
# %pylab inline

plt.imshow(im)
plt.axis('off');
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Documentation

# %% [markdown]
# [Open CV tutorials](https://docs.opencv.org/3.0-beta/doc/py_tutorials/py_tutorials.html)

# %% [markdown]
# ## Benchmarking

# %% [markdown]
# [This kaggle post](https://www.kaggle.com/vfdev5/pil-vs-opencv) illustrates that `OpenCV` blows `Pillow` out of the water when performing multiple, repeated transformations over multiple files.
