# %% [raw]
# ---
# title: "Logical Operations"
# author: "Chris Albon"
# date: 2017-12-20T11:53:49-07:00
# description: "Logical Operations in Python."
# type: technical_note
# draft: false
# ---

# %% [markdown]
# ### Create some simulated variables

# %%
x = 6

# %%
y = 9

# %%
z = 12

# %% [markdown]
# ### x or y

# %%
x or y
# Out:
# 6

# %% [markdown]
# ### x and y

# %%
x and y
# Out:
# 9

# %% [markdown]
# ### not x

# %%
not x
# Out:
# False

# %% [markdown]
# ### x is equal to y

# %%
x == y
# Out:
# False

# %% [markdown]
# ### x is not equal to y

# %%
x != y
# Out:
# True

# %% [markdown]
# ### One is less than two

# %%
1 < 2
# Out:
# True

# %% [markdown]
# ### Two is less than or equal to four

# %%
2 <= 4
# Out:
# True

# %% [markdown]
# ### Three is equal to five

# %%
3 == 5
# Out:
# False

# %% [markdown]
# ### Three is not equal to four

# %%
3 != 4
# Out:
# True

# %% [markdown]
# ### x is less than y which is less than z

# %%
x < y < z
# Out:
# True

# %% [markdown]
# ### x is less than y and y is less than z

# %%
x < y and y < z
# Out:
# True
